# %% [markdown]
# # Representación de Problemas, Búsqueda y Fundamentos Matemáticos de IA
# ## Representación de un problema mediante estados

# %% [markdown]
# Parte A: Completar la cha del problema para el siguiente caso: un repartidor debe ir desde el
# Almacén hasta la Zona Norte, pudiendo pasar por distintos puntos intermedios de la ciudad.

# %% [markdown]
# | Estado  | Detalle |
# | :--- | :--- |
# | **Estado inicial** | El repartidor está en el almacén |
# | **Estado objetivo** | El repartidor está en la zona norte |
# | **Acciones posibles** | El repartidor puede movilizarse a cualquier otro punto cercano |
# | **Costo de cada acción** | El valor de 1 para cualquiera de los tramos |

# %% [markdown]
# ## Representar el mapa de la ciudad como un grafo en Python

# %% [markdown]
# Usamos un diccionario de listas mpara representar el mapa de la ciudad

# %%
mapa = {
"Almacen": ["Centro", "Terminal"],
"Centro": ["Almacen", "ZonaNorte", "Mercado"],
"Terminal": ["Almacen", "Mercado"],
"Mercado": ["Centro", "Terminal", "ZonaNorte"],
"ZonaNorte": ["Centro", "Mercado"],
}
print(mapa)
# Out:
# {'Almacen': ['Centro', 'Terminal'], 'Centro': ['Almacen', 'ZonaNorte', 'Mercado'], 'Terminal': ['Almacen', 'Mercado'], 'Mercado': ['Centro', 'Terminal', 'ZonaNorte'], 'ZonaNorte': ['Centro', 'Mercado']}

# %% [markdown]
# ### Implementación de BFS

# %% [markdown]
# Incializamos definiendo la funcion BFS con tre puntos importantes Grafo, inicico y objetivo, donde la cola = al incio, en este caso inicio = almacen, asi mismo creamos una lista vacía con set ()

# %%
def bfs(grafo, inicio, objetivo):
cola = [[inicio]]
visitados = set()

# %% [markdown]
# Luego continuamos con el while para realizar la exploracion de los caminos de un punto a otro, dela misma manera definimos el camino y el nodo actual, la variable camino será el amazen del ese camino en ceustion, el cual será el primer valor de nuestro mapa, luego definicmo Nodo actual con el ultimo termino del camino en este caso -1.

# %%
while cola:
        camino = cola.pop(0)
        nodo_actual = camino[-1]

# %% [markdown]
# Definimos un if simple para verficar que el ultimo nodo del camino es el mismo que el objetivo si lo es ya tenemo el camino y si no pasamos al siguien bloque de codigo

# %%
        if nodo_actual == objetivo:
            return camino

# %% [markdown]
# Luego verificamos si el nodo actual a sido recorrido antes, y luego agregamos nuestro nuevo camino  a la lista creada al inico para tener un registro de lso camino ya realizados

# %%
        if nodo_actual not in visitados:
                    visitados.add(nodo_actual)
                    for vecino in grafo[nodo_actual]:
                        nuevo_camino = camino + [vecino]
                        cola.append(nuevo_camino)
        return None

# %% [markdown]
# Por ultimo imrpimimos el resultado y lo mostrmos en pantalla

# %%
resultado_bfs = bfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado (BFS):", resultado_bfs)

# %% [markdown]
# ## Vectores y matrices con NumPy

# %% [markdown]
# Primeramente creamos la variables de observaciones y la colocamos en una matriz de tal forma que los vectores esten organizados

# %%
import numpy as np
obs1 = np.array([22.5, 60]) 
obs2 = np.array([19.0, 45])
obs3 = np.array([25.3, 70])
obs4 = np.array([21.0, 50])
dataset = np.array([obs1, obs2, obs3, obs4])
print(dataset)
print("Forma de la matriz (filas, columnas):", dataset.shape)

# %% [markdown]
# Consecuentemenmte calculamos el prducto escalar usando np.dont

# %%
producto = np.dot(obs1, obs2)
print("Producto escalar entre obs1 y obs2:", producto)

# %% [markdown]
# realizamos el calculo e manera manual sin usar numpy

# %%
distancia_manual = np.sqrt(np.sum((obs1 - obs2) ** 2))
print("Distancia manual:", distancia_manual)

# %% [markdown]
# de la misma manera tenemos una forma mas abreviada usando numpy especificamente el np.linalg.norm

# %%
distancia_numpy = np.linalg.norm(obs1 - obs2)
print("Distancia con NumPy:", distancia_numpy)
